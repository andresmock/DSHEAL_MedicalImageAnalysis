# %%
import os
import wandb
import pandas as pd

# %%
login_file = ".wandb_login"

if os.path.exists(login_file):
    with open(login_file, "r") as f:
        for line in f:
            if line.startswith("WANDB_API_KEY="):
                os.environ["WANDB_API_KEY"] = line.strip().split("=")[1]
                break

wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mockand1 (mockand1-ba) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()

# Dein W&B-Projekt auswählen
project_name = "mockand1-ba/DSHEAL_pro1_FS25_GaMo"

# Alle gespeicherten Runs abrufen
runs = api.runs(project_name)

# %%
# Runs in ein DataFrame konvertieren
history = []

for run in runs:
    df = run.history(keys=["Epoch", "Train Accuracy", "Validation Accuracy", "Loss"])
    df["run_id"] = run.id
    df["run_name"] = run.name
    history.append(df)

# Alle Runs zusammenfügen
df_wandb = pd.concat(history, ignore_index=True)
df_wandb
# Out:
#     _step  Epoch  Train Accuracy  Validation Accuracy      Loss    run_id  \
# 0     689      1        0.646272             0.690018  0.627436  cy632uhj
# 1    1379      2        0.696344             0.731034  0.584967  cy632uhj
# 2    2069      3        0.777168             0.864610  0.494088  cy632uhj
# 3    2759      4        0.875771             0.897278  0.329752  cy632uhj
# 4    3449      5        0.916727             0.936479  0.237696  cy632uhj
# 5    4139      6        0.932148             0.941198  0.202435  cy632uhj
# 6    4829      7        0.938906             0.946279  0.188540  cy632uhj
# 7    5519      8        0.942671             0.948457  0.181501  cy632uhj
# 8    6209      9        0.941854             0.951724  0.176391  cy632uhj
# 9    6899     10        0.944077             0.948094  0.172314  cy632uhj
# 10   7589     11        0.945800             0.952813  0.170187  cy632uhj
# 11   8279     12        0.947524             0.951361  0.167915  cy632uhj
# 12   8969     13        0.949701             0.945917  0.163026  cy632uhj
# 13   9659     14        0.947569             0.956806  0.162473  cy632uhj
# 14  10349     15        0.950290             0.952813  0.156564  cy632uhj
#
#             run_name
# 0   MalariaNet_andre
# 1   MalariaNet_andre
# 2   MalariaNet_andre
# 3   MalariaNet_andre
# 4   MalariaNet_andre
# 5   MalariaNet_andre
# 6   MalariaNet_andre
# 7   MalariaNet_andre
# 8   MalariaNet_andre
# 9   MalariaNet_andre
# 10  MalariaNet_andre
# 11  MalariaNet_andre
# 12  MalariaNet_andre
# 13  MalariaNet_andre
# 14  MalariaNet_andre
